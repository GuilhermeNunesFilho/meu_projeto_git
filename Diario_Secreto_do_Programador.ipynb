# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeNunesFilho/meu_projeto_git/blob/main/Diario_Secreto_do_Programador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Salvando informações permanente

while True:
  ler_pensamentos = ""
  print("-------Menu-------")
  print("1: Escrever no Diário")
  print("2: Ler Diário")
  print("3: Sair")
  print("4: Escluir Pensamentos")
  print("-"*30)

  try:
    opcao = int(input("Oque deseja fazer?\n"))
  except ValueError:
    print("Opção invalida!")

  if opcao == 1:
    ler_pensamentos = input("Digite seu pensamento aqui:\n")
    # Criando o arquivo diario.txt para salvar as informações

    with open("diario.txt", "a") as arquivo:
      arquivo.write(ler_pensamentos + "\n")
  elif opcao == 2:
    # Lendo as informações obtidas

    with open("diario.txt", "r") as arquivo:

      ler_pensamentos = arquivo.read()
      print("-"*30)
      print(ler_pensamentos)
      print("-"*30)

  elif opcao == 4:
    # Limpando as informações do arquivo diario.txt

     with open("diario.txt", "w") as arquivo:
      arquivo.write("")
      print("Arquivo resetado! Sucesso")
  else:
    print("finalizando...")
    break
# Out:
# -------Menu-------
# 1: Escrever no Diário
# 2: Ler Diário
# 3: Sair
# 4: Escluir Pensamentos
# ------------------------------
# Oque deseja fazer?
# 1
# Digite seu pensamento aqui:
# amo programar
# -------Menu-------
# 1: Escrever no Diário
# 2: Ler Diário
# 3: Sair
# 4: Escluir Pensamentos
# ------------------------------
# Oque deseja fazer?
# 2
# ------------------------------
#
#
# amo programar
#
# ------------------------------
# -------Menu-------
# 1: Escrever no Diário
# 2: Ler Diário
# 3: Sair
# 4: Escluir Pensamentos
# ------------------------------
# Oque deseja fazer?
# 4
# Arquivo resetado! Sucesso
# -------Menu-------
# 1: Escrever no Diário
# 2: Ler Diário
# 3: Sair
# 4: Escluir Pensamentos
# ------------------------------
# Oque deseja fazer?
# 2
# ------------------------------
#
# ------------------------------
# -------Menu-------
# 1: Escrever no Diário
# 2: Ler Diário
# 3: Sair
# 4: Escluir Pensamentos
# ------------------------------
# Oque deseja fazer?
# 3
# ...
